# %%
import pandas as pd
import numpy as np
import copy
import time
import json
from tweet_input_output_functions import obtain_tweet, extract_information_from_tweet_json
from tweet_analysis_functions import prefilter_tweet
import sqlite3_connection
import postgres_connection


def main(db_type):

    #nlp = spacy.load('ja_ginza_electra')  #No idea when to deal with this
    tweet_data_frame_list = []
    tweet_users_frame_list = []
    start_dates=["2018-01-01","2018-04-01","2018-07-01","2018-10-01","2022-01-01","2022-04-01","2022-07-01","2022-10-01"]
    end_dates=["2018-03-31","2018-06-30","2018-09-30","2018-12-31","2022-03-31","2022-06-30","2022-09-30","2022-12-31"]

    text_file = open('tweet_queries.txt', 'r')
    
    lines = text_file.readlines()

    location_category = None

    counter = 0

    for line in lines:
        # Get next line from file

        print(f"counter: {counter}")
        
        if line[0] == "=":
            location_category = line.split("=")[-1]
            print(f"new category: {location_category}")

        elif line[0] != "=":

            location_keyword = line
            counter += 1

            for c in ['\\', '&', '.', '"', "'", "and"]: #The requests module doesn't like these characters, so we need to add a preventative backslash
                if c in line:
                    location_keyword = line.replace(c, "\\"+c)

            print(f"location category: {location_category}")
            print(f"location keyword: {location_keyword}")
            

            for start_date, end_date in zip(start_dates, end_dates):
                json_tweet = obtain_tweet(location_keyword , start_date, end_date)
                # Serializing json
                json_object = json.dumps(json_tweet)
                with open("log.txt", "w") as outfile:
                    outfile.write(json_object)
                time.sleep(2.5) #To avoid too many requests error
                
                try:
                    json_tweet["meta"] # Test if service is available (too many requests, or service unavailable)
                except KeyError:
                    print("key error")
                    flag = None
                    while flag is None:
                        print('waiting')
                        time.sleep(5) #Wait a bit in case service comes back online
                        json_tweet = obtain_tweet(location_keyword , start_date, end_date) #Then request again
                        print(flag)
                        try:
                            flag = json_tweet["meta"]
                            print("flag exists")
                            print(json_tweet)
                        except KeyError:
                            print("service still unavailable")
                            print(json_tweet)
                else: 
                    print("tweet exists") # If everything is OK, and the try statement works, print this
                    
                if json_tweet["meta"]["result_count"] == 0:# also need to check length here
                    print('tweet exists but no relevant results')
                    print('moving on to next keyword in list')
                    continue # Just go back to start of for loop and continue
                    
                else:
                    print('relevant results exist and will be logged')

                tweet_data_frame, tweet_users_frame = extract_information_from_tweet_json(*prefilter_tweet(json_tweet), location_keyword, location_category) #asterisk to unpack the two returned values and use as inputs
                tweet_data_frame_list.append(tweet_data_frame)
                tweet_users_frame_list.append(tweet_users_frame)
                
                print('moving on to next keyword in list')
        else:
            print("file reading error, moving to next line and trying again")
    text_file.close()
    print('finished running through text file')
    
    if db_type == 'sqlite':
        sqlite3_connection.create_sqlite_database('scrapedtweets.db', tweet_data_frame_list, tweet_users_frame_list)
    elif db_type == 'postgres':
        concat_tweet_data_frame = pd.concat(tweet_data_frame_list)
        concat_tweet_users_frame = pd.concat(tweet_users_frame_list)
        postgres_connection.create_postgres_database(concat_tweet_data_frame, concat_tweet_users_frame, 'data_table', 'users_table')
    else:
        print('please specify a db type')


main(db_type = 'postgres')

print("finished")
# Out:
# counter: 0
# counter: 0
# (荒津山 OR #荒津山)  (Fukuoka OR 福岡 OR Chuo OR 中央区)
#
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not write a description
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not write a description
# moving on to next keyword in list
# counter: 1
# (荒平山 OR #荒平山)  (Fukuoka OR 福岡 OR Sawara OR 早良区)
#
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# moving on to next keyword in list
# counter: 2
# (毘沙門山 OR #毘沙門山)  (Fukuoka OR 福岡 OR Nishi OR 西区)
#
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# moving on to next keyword in list
# counter: 3
# counter: 3
# (や台ずし OR #や台ずし)  (Fukuoka OR 福岡 OR Higashi OR 東区)
#
# tweet exists
# relevant results exist and will be logged
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# moving on to next keyword in list
# counter: 4
# (中屋イオン香椎浜店 OR #中屋イオン香椎浜店)  (Fukuoka OR 福岡 OR Higashi OR 東区)
#
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# counter: 5
# (くいもんや横丁 OR #くいもんや横丁)  (Fukuoka OR 福岡 OR Higashi OR 東区)
#
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# counter: 6
# (イオンラウンジ 香椎浜 OR #イオンラウンジ香椎浜)  (Fukuoka OR 福岡 OR Higashi OR 東区)
#
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# counter: 7
# (かえるのへそ OR #かえるのへそ)  (Fukuoka OR 福岡 OR Higashi OR 東区)
#
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# counter: 8
# (海鮮食堂 い志い 照葉 OR #海鮮食堂い志い照葉)  (Fukuoka OR 福岡 OR Higashi OR 東区)
#
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# moving on to next keyword in list
# counter: 9
# (馬刺し馬肉料理専門店波津馬福岡店 OR #馬刺し馬肉料理専門店波津馬福岡店)  (Fukuoka OR 福岡 OR Higashi OR 東区)
#
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# counter: 10
# (博多一番どり居食家あらい スポーツガーデン香椎店 OR #博多一番どり居食家あらいスポーツガーデン香椎店)  (Fukuoka OR 福岡 OR Higashi OR 東区)
#
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# counter: 11
# (隠れ家 ちはや OR #隠れ家ちはや)  (Fukuoka OR 福岡 OR Higashi OR 東区)
#
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# counter: 12
# (bar cutty sark OR #barcuttysark)  (Fukuoka OR 福岡 OR Higashi OR 東区)
#
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# counter: 13
# (auramore OR #auramore)  (Fukuoka OR 福岡 OR Higashi OR 東区)
#
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# counter: 14
# (や台ずし 香椎駅前町 OR #や台ずし香椎駅前町)  (Fukuoka OR 福岡 OR Higashi OR 東区)
#
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# counter: 15
# (west gate OR #westgate)  (Fukuoka OR 福岡 OR Higashi OR 東区)
#
# tweet exists
# relevant results exist and will be logged
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# deleting tweet
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# deleting tweet
# moving on to next keyword in list
# counter: 16
# (庄屋 イオン香椎浜店 OR #庄屋イオン香椎浜店)  (Fukuoka OR 福岡 OR Higashi OR 東区)
#
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# counter: 17
# (魚 きんぐ イオンモール香椎浜店 OR #魚きんぐイオンモール香椎浜店)  (Fukuoka OR 福岡 OR Higashi OR 東区)
#
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# counter: 18
# (卵のアート イオンモール香椎浜店 OR #卵のアートイオンモール香椎浜店)  (Fukuoka OR 福岡 OR Higashi OR 東区)
#
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# counter: 19
# (楽天地 OR #楽天地)  (Fukuoka OR 福岡 OR Higashi OR 東区)
#
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not write a description
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# deleting tweet
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# deleting tweet
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# counter: 20
# (風雅 OR #風雅)  (Fukuoka OR 福岡 OR Higashi OR 東区)
#
# tweet exists
# relevant results exist and will be logged
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not write a description
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# deleting tweet
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# counter: 21
# (ichie OR #ichie)  (Fukuoka OR 福岡 OR Higashi OR 東区)
#
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# deleting tweet
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# deleting tweet
# deleting tweet
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# deleting tweet
# deleting tweet
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# moving on to next keyword in list
# counter: 22
# (波津馬福岡店 OR #波津馬福岡店)  (Fukuoka OR 福岡 OR Higashi OR 東区)
#
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# counter: 23
# (partire 千早 OR #partire千早)  (Fukuoka OR 福岡 OR Higashi OR 東区)
#
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# moving on to next keyword in list
# counter: 24
# (パルティーレ千早 OR #パルティーレ千早)  (Fukuoka OR 福岡 OR Higashi OR 東区)
#
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# counter: 25
# (いざかやあたる OR #いざかやあたる)  (Fukuoka OR 福岡 OR Higashi OR 東区)
#
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# ...
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not write a description
# This user did not write a description
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# deleting tweet
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# deleting tweet
# deleting tweet
# This user did not write a description
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# counter: 357
# (蛸よし OR #蛸よし)  (Fukuoka OR 福岡 OR Minami OR 南区)
#
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# counter: 358
# (楽香園 OR #楽香園)  (Fukuoka OR 福岡 OR Minami OR 南区)
#
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# counter: 359
# (チャイニーズキッチンちゃん OR #チャイニーズキッチンちゃん)  (Fukuoka OR 福岡 OR Minami OR 南区)
#
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
# counter: 360
# (兎屋 OR #兎屋)  (Fukuoka OR 福岡 OR Minami OR 南区)
#
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# This user did not write a description
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# This user did not specify a location
# This user did not specify a location
# moving on to next keyword in list
# tweet exists
# relevant results exist and will be logged
# This user did not specify a location
# moving on to next keyword in list
# counter: 361
# (かっぱ寿司福岡長丘店 OR #かっぱ寿司福岡長丘店)  (Fukuoka OR 福岡 OR Minami OR 南区)
#
# tweet exists
# tweet exists but no relevant results
# moving on to next keyword in list
